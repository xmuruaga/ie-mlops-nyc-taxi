# %% [markdown]
# ## Scenario 1: A single data scientist participating in an ML competition
#
# This scenario demonstrates how an individual data scientist can use MLflow to track machine learning experiments on their local machine. This is a common setup for solo projects, hackathons, or competitions where collaboration and remote access are not required.
#
# ### MLflow setup overview
# - **Tracking server:** Not used (runs locally, no remote server)
# - **Backend store:** Local filesystem (stores experiment metadata in the `mlruns/` folder)
# - **Artifacts store:** Local filesystem (stores model files and other artifacts in the same `mlruns/` folder)
#
# With this setup, all experiment runs, parameters, metrics, and artifacts are saved locally. You can explore and compare your experiments using the MLflow UI.
#
# ### How to use the MLflow UI
# - You can launch the MLflow UI by running `mlflow ui` in your terminal, or by running the provided code cell in this notebook.
# - The UI will be available at [http://localhost:5000](http://localhost:5000).
# - Use the UI to browse experiments, compare runs, and inspect logged models and artifacts.
#
# > **Tip:** This local setup is ideal for learning and prototyping. For team projects or production, you would typically use a remote tracking server and a more robust backend (e.g., a database and cloud storage).

# %%
# %pip install mlflow
import mlflow
# Out:
# Requirement already satisfied: mlflow in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (3.3.2)
# Requirement already satisfied: mlflow-skinny==3.3.2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (3.3.2)
# Requirement already satisfied: mlflow-tracing==3.3.2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (3.3.2)
# Requirement already satisfied: Flask<4 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (1.13.2)
# Requirement already satisfied: cryptography<46,>=43.0.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: matplotlib<4 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (3.8.2)
# Requirement already satisfied: numpy<3 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (1.26.3)
# Requirement already satisfied: pandas<3 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (2.2.0)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (1.4.0)
# Requirement already satisfied: scipy<2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (1.12.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (2.0.46)
# Requirement already satisfied: waitress<4 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.65.0)
# Requirement already satisfied: fastapi<1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.116.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (6.11.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (1.36.0)
# Requirement already satisfied: packaging<26 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (6.32.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (4.12.2)
# Requirement already satisfied: uvicorn<1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.37.0)
# Requirement already satisfied: Mako in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: colorama in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from click<9,>=7.0->mlflow-skinny==3.3.2->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=1.14 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from cryptography<46,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (2.40.3)
# Requirement already satisfied: pywin32>=304 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from docker<8,>=4.0.0->mlflow) (306)
# Requirement already satisfied: urllib3>=1.26.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from docker<8,>=4.0.0->mlflow) (2.2.3)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from fastapi<1->mlflow-skinny==3.3.2->mlflow) (0.47.3)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from Flask<4->mlflow) (2.1.5)
# Requirement already satisfied: werkzeug>=3.1.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (4.7.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.3.2->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib<4->mlflow) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib<4->mlflow) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=8 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib<4->mlflow) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib<4->mlflow) (3.1.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.3.2->mlflow) (0.57b0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (2024.8.30)
# Requirement already satisfied: pyasn1>=0.1.3 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from scikit-learn<2->mlflow) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from scikit-learn<2->mlflow) (3.2.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.3.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow) (4.5.0)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from uvicorn<1->mlflow-skinny==3.3.2->mlflow) (0.14.0)
# Requirement already satisfied: pycparser in C:\Users\Administrador\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'file:///c:/Users/Administrador/Desktop/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///c:/Users/Administrador/Desktop/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1772554428738, experiment_id='0', last_update_time=1772554428738, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import mlflow
import sklearn
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mlflow.set_experiment("my-experiment-1")

X, y = load_iris(return_X_y=True)
class_names = load_iris().target_names

models = [
    ("LogisticRegression", LogisticRegression(C=1.0, random_state=42, max_iter=1000, solver="lbfgs")),
    ("RandomForestClassifier", RandomForestClassifier(n_estimators=100, random_state=42))
]

for model_name, model in models:
    with mlflow.start_run() as run:
        mlflow.set_tag("model_type", model_name)
        mlflow.log_param("sklearn_version", sklearn.__version__)
        model.fit(X, y)
        y_pred = model.predict(X)
        acc = accuracy_score(y, y_pred)
        mlflow.log_metric("accuracy", acc)
        # Log confusion matrix as labeled DataFrame
        cm = confusion_matrix(y, y_pred)
        cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
        cm_df.to_csv("confusion_matrix_labeled.csv")
        mlflow.log_artifact("confusion_matrix_labeled.csv")
        # Confusion matrix heatmap as image
        plt.figure(figsize=(5,4))
        sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
        plt.title(f"Confusion Matrix ({model_name})")
        plt.ylabel("True label")
        plt.xlabel("Predicted label")
        plt.tight_layout()
        plt.savefig("confusion_matrix_heatmap.png")
        plt.close()
        mlflow.log_artifact("confusion_matrix_heatmap.png")
        # Provide input_example and use 'name' instead of deprecated 'artifact_path'
        input_example = np.expand_dims(X[0], axis=0)
        mlflow.sklearn.log_model(model, name="models", input_example=input_example)
        mlflow.set_tag("n_classes", len(np.unique(y)))
        mlflow.set_tag("run_time", datetime.datetime.now().isoformat())
        mlflow.set_tag("description", f"{model_name} on Iris dataset")
        print(f"Logged run for {model_name}, accuracy={acc:.3f}")
# Out:
# 2026/03/03 17:13:58 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Logged run for LogisticRegression, accuracy=0.973
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Logged run for RandomForestClassifier, accuracy=1.000

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///c:/Users/Administrador/Desktop/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/321328011898983440', creation_time=1772554438698, experiment_id='321328011898983440', last_update_time=1772554438698, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='file:///c:/Users/Administrador/Desktop/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1772554428738, experiment_id='0', last_update_time=1772554428738, lifecycle_stage='active', name='Default', tags={}>]

# %%
# Launch MLflow UI (default: uses local mlruns/ folder)
import subprocess
import sys

# This will run 'mlflow ui' as a background process
subprocess.Popen([sys.executable, '-m', 'mlflow', 'ui'])
print("MLflow UI started. Open http://localhost:5000 in your browser.")
# Out:
# MLflow UI started. Open http://localhost:5000 in your browser.

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
